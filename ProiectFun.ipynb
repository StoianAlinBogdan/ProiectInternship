# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r"C:\Users\alstoian\Downloads\NYPD_Arrests_Data__Historic_.csv")

# %%
x = np.sort(data["ARREST_PRECINCT"].unique())
myfilter = [item for item in range(0, 14)]
myfilter.extend([17, 19, 20])
myfilter.extend([item for item in range(23, 150)])
y = [a for a in x if a not in myfilter]
print(y)
# Out:
# [14, 18, 22]

# %%
np.count_nonzero(data["JURISDICTION_CODE"].unique())
# Out:
# 26

# %%
np.count_nonzero(data["LAW_CODE"].unique())
# Out:
# 2441

# %%
np.count_nonzero(data["KY_CD"].unique())
# Out:
# 76

# %%
np.count_nonzero(data["PD_CD"].unique())
# Out:
# 334

# %%
len(data)
# Out:
# 5153369

# %%
data.dropna(inplace=True)
len(data)
# Out:
# 5125606

# %%
data.memory_usage()
# Out:
# Index                41004848
# ARREST_KEY           41004848
# ARREST_DATE          41004848
# PD_CD                41004848
# PD_DESC              41004848
# KY_CD                41004848
# OFNS_DESC            41004848
# LAW_CODE             41004848
# LAW_CAT_CD           41004848
# ARREST_BORO          41004848
# ARREST_PRECINCT      41004848
# JURISDICTION_CODE    41004848
# AGE_GROUP            41004848
# PERP_SEX             41004848
# PERP_RACE            41004848
# X_COORD_CD           41004848
# Y_COORD_CD           41004848
# dtype: int64

# %%
#del data["Latitude"]
#del data["Longitude"]
del data["Lon_Lat"]
data.memory_usage().sum()
# Out:
# 779092112

# %%
data
# Out:
#          ARREST_KEY ARREST_DATE  PD_CD                         PD_DESC  KY_CD  \
# 1         192799737  01/26/2019  177.0                    SEXUAL ABUSE  116.0
# 3         149117452  01/06/2016  153.0                          RAPE 3  104.0
# 4         190049060  11/15/2018  157.0                          RAPE 1  104.0
# 5          24288194  09/13/2006  203.0            TRESPASS 3, CRIMINAL  352.0
# 6         189182271  10/24/2018  153.0                          RAPE 3  104.0
# ...             ...         ...    ...                             ...    ...
# 5153364   207601040  01/08/2020  273.0            TAMPERING 1,CRIMINAL  121.0
# 5153365   206891807  01/01/2020  113.0           MENACING,UNCLASSIFIED  344.0
# 5153366   207760542  01/11/2020  339.0  LARCENY,PETIT FROM OPEN AREAS,  341.0
# 5153367   206896678  01/01/2020  105.0               STRANGULATION 1ST  106.0
# 5153368   206908101  01/02/2020  782.0        WEAPONS, POSSESSION, ETC  236.0
#
# ...

# %%
data.to_csv('NYPD_Arrests_Historic_Final.csv', index=False)

# %%
np.count_nonzero(data["X_COORD_CD"].unique())
# Out:
# 64165

# %%
data.duplicated(subset=["X_COORD_CD"])
# Out:
# 1          False
# 3          False
# 4          False
# 5          False
# 6          False
#            ...
# 5153364     True
# 5153365     True
# 5153366     True
# 5153367     True
# 5153368     True
# Length: 5125606, dtype: bool

# %%
data[data.duplicated(keep=False, subset=["X_COORD_CD"])]
# Out:
#          ARREST_KEY ARREST_DATE  PD_CD                         PD_DESC  KY_CD  \
# 1         192799737  01/26/2019  177.0                    SEXUAL ABUSE  116.0
# 3         149117452  01/06/2016  153.0                          RAPE 3  104.0
# 4         190049060  11/15/2018  157.0                          RAPE 1  104.0
# 5          24288194  09/13/2006  203.0            TRESPASS 3, CRIMINAL  352.0
# 6         189182271  10/24/2018  153.0                          RAPE 3  104.0
# ...             ...         ...    ...                             ...    ...
# 5153364   207601040  01/08/2020  273.0            TAMPERING 1,CRIMINAL  121.0
# 5153365   206891807  01/01/2020  113.0           MENACING,UNCLASSIFIED  344.0
# 5153366   207760542  01/11/2020  339.0  LARCENY,PETIT FROM OPEN AREAS,  341.0
# 5153367   206896678  01/01/2020  105.0               STRANGULATION 1ST  106.0
# 5153368   206908101  01/02/2020  782.0        WEAPONS, POSSESSION, ETC  236.0
#
# ...

# %%
data[(data["PD_CD"] == 177.0) & (data["KY_CD"] == 116.0)]
# Out:
#          ARREST_KEY ARREST_DATE  PD_CD       PD_DESC  KY_CD   OFNS_DESC  \
# 1         192799737  01/26/2019  177.0  SEXUAL ABUSE  116.0  SEX CRIMES
# 153       194164531  03/01/2019  177.0  SEXUAL ABUSE  116.0  SEX CRIMES
# 189       195242031  03/27/2019  177.0  SEXUAL ABUSE  116.0  SEX CRIMES
# 221       195915501  04/12/2019  177.0  SEXUAL ABUSE  116.0  SEX CRIMES
# 282       198369941  06/12/2019  177.0  SEXUAL ABUSE  116.0  SEX CRIMES
# ...             ...         ...    ...           ...    ...         ...
# 5149114   207835939  01/13/2020  177.0  SEXUAL ABUSE  116.0  SEX CRIMES
# 5149306   207590575  01/08/2020  177.0  SEXUAL ABUSE  116.0  SEX CRIMES
# 5152451   207490642  01/06/2020  177.0  SEXUAL ABUSE  116.0  SEX CRIMES
# 5152892   206921948  01/04/2020  177.0  SEXUAL ABUSE  116.0  SEX CRIMES
# 5153012   207740396  01/10/2020  177.0  SEXUAL ABUSE  116.0  SEX CRIMES
#
#            LAW_CODE LAW_CAT_CD ARREST_BORO  ARREST_PRECINCT  \
# ...

# %%
data[(data["ARREST_PRECINCT"] == 25) & (data["ARREST_BORO"] != "M")]
# Out:
# Empty DataFrame
# Columns: [ARREST_KEY, ARREST_DATE, PD_CD, PD_DESC, KY_CD, OFNS_DESC, LAW_CODE, LAW_CAT_CD, ARREST_BORO, ARREST_PRECINCT, JURISDICTION_CODE, AGE_GROUP, PERP_SEX, PERP_RACE, X_COORD_CD, Y_COORD_CD, Latitude, Longitude]
# Index: []
